# %%
from matplotlib import pyplot as plt

# %%
#data
x = [1, 2, 3]
y = [1, 4, 9]

#plot
plt.plot(x, y)

#style
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.legend(["this is a line"])

#plot show command
plt.show()
